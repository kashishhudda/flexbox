# %% [markdown]
# 1. Describe the main differences between the CSS Flexbox layout model and the CSS Grid layout model. When would you choose to use one over the other?
#   - Layout Dimension
#
# Flexbox → One-dimensional (manages layout in a single row or a single column).
#
# Grid → Two-dimensional (manages layout across both rows and columns).
#
#   - Content vs. Container
#
# Flexbox → Focused on distributing and aligning items based on content size.
#
# Grid → Focused on defining a fixed structure of rows and columns first, then placing items.
#
#   - Alignment & Control
#
# Flexbox → Strong control for spacing, alignment, and order along one axis.
#
# Grid → Strong control for precise placement in both directions (row + column).
#
# ----> When to Use Which
#
#   - Use Flexbox when working with a single row or column and you need flexible alignment/distribution.
#
#   - Use Grid when working with full layouts or components that need both rows and columns for structure.

# %% [markdown]
# 2. Explain the role of the following key properties in the Flexbox layout mode
#  justify-content,align-items,gap,flex-direction,flex-wrap.
#  - justify-content
#     - Aligns the entire flex container's items along the main axis.
#     - Possible values: flex-start, flex-end, center, space-between, space-around, space-evenly.
#     - Determines how space is distributed around items.
#  - align-items
#    - Aligns flex items along the cross-axis.
#    - Possible values: stretch, center, flex-start, flex-end.
#    - The default value is stretch.
#  - gap
#    - Sets the spacing between items in a flex container.
#    - Can be defined for rows (row-gap) and columns (column-gap), or both (gap).
#    - Useful for creating consistent spacing without margins.
#  - flex-direction
#    - Specifies the direction of the flex items in the flex container.
#    - Possible values: row, row-reverse, column, column-reverse.
#    - Determines the main axis direction (horizontal or vertical).
#  - flex-wrap
#    - Controls whether flex items are forced into a single line or can wrap onto multiple lines.
#    - Possible values: nowrap, wrap, wrap-reverse.
#    - The default value is nowrap.

# %% [markdown]
# 3. Write the code to center a div using CSS Flexbox.

# %%
< !DOCTYPE html>
< html lang="en">
< head>
    < meta charset="UTF-8">
    < meta name="viewport" content="width=device-width, initial-scale=1.0">
    < title>div< /title>
    < style>
    < link rel="stylesheet" href="style.css">
    < /style>
< /head>
< body>
    < div>< /div>
< /body>
< /html>

"""External CSS"""
        body{
            margin: 0;
            display: flex;
            justify-content: center;
            align-items: center;
            height: 100vh;
        }
        div{
             background-color: rgb(33, 33, 102);
              height: 30vh;
             width: 100px;
             display: flex;
             justify-content: center;
             align-items:center;

        }

# %% [markdown]
# 4.  A client of yours wants to add a pricing section on their website to showcase their newly introduced premium plans.You have to build the pricing section for their business. They have provided you with the figma design for the
# same. Link

# %%
< !DOCTYPE html>
< html lang="en">
< head>
    < meta charset="UTF-8">
    < meta name="viewport" content="width=device-width, initial-scale=1.0">
    < title>Pricing cards< /title>
    < link rel="stylesheet" href="style3.css">
< /head>
< body>
    <!-- Free plan -->
    < div class="pricing-container">
        < div class="card">
            < h2>Free Plan< /h2>
            < p>For personal< /p>
        < div class="price">$0< /div>
        < ul>
            < li>1 users< /li>
            < li>4 Web mails< /li>
            < li>Responsive Website< /li>
            < li>Free SSL< /li>
        < /ul>
        < a href="#" class="btn">Subscribe Now< /a>
        < /div>

    <!-- Basic Plan -->

        < div class="card highlight">
            < h2>Basic Plan< /h2>
            < p>For small business< /p>
        < div class="price">$29< /div>
        < ul>
            < li>4 users< /li>
            < li>10 Web mails< /li>
            < li>Responsive Website< /li>
            < li>Free SSL< /li>
        < /ul>
        < a href="#" class="btn">Subscribe Now< /a>
        < /div>

    <!-- Pro Plan -->

        < div class="card">
            < h2>Pro Plan< /h2>
            < p>For enterprise< /p>
        < div class="price">$49< /div>
        < ul>
            < li>Unlimited users< /li>
            < li>Unlimited Web mails< /li>
            < li>Responsive Websites< /li>
            < li>Free SSL + SEO< /li>
        < /ul>
        < a href="#" class="btn">Subscribe Now< /a>
        < /div>
< /body>
< /html>

"""External CSS"""
body{
    background-color:  #0b0722;
    display: flex;
    justify-content: center;
    align-items: center;
    margin: 0;
    font-family: Arial,sans-serif;
    height: 100vh;
}
.pricing-container{
    display: flex;
    justify-content: center;
    gap: 20px;
}
.card{
    background-color: white;
    width: 250px;
    margin: 10px;
    padding: 25px 20px;
    text-align: center;
    box-shadow:0 4px 10px rgba(0,0,0,0.1);
    transition: transform 0.3s ease,box-shadow 0.3s ease-in;
    border-radius: 20px;
}
.card:hover{
    transform: translateY(-30px);
    box-shadow:0 4px 10px rgba(15, 15, 15, 0.1) ;
}
.card h2{
    margin:0px;
    font-size: 25px;
}
.card p{
    color: gray;
    margin: 6px 0;
}
.price{
    font-size: 28px;
    font-weight: bold;
    margin: 15px 0;
}
ul{
    list-style: none;
    text-align: left;
    margin: 15px 0;
    padding: 0;
}
ul li{
  padding-left: 20px;
  margin: 8px 0px;
  position: relative;
}
ul li::before{
    content: "✔";
    position: absolute;
    left: 0;
    color: rgb(9, 83, 9);
}
.btn{
    background-color: rgb(12, 12, 68);
    color: white;
    padding: 10px 20px;
    border-radius: 20px;
    text-decoration: none;
    display: inline-block;
    margin: 0;
    transition: background-color 0.3s ease, color 0.3s ease;
}
.btn:hover{
    background-color: rgb(30, 30, 87);
}
.highlight{
    background-color: rgba(30, 30, 82, 0.89);
    color: white;
}
.highlight .btn{
    background-color: white;
    color: rgb(2, 2, 66);
    font-weight: bolder;
}
.highlight .btn:hover{
    background-color: rgb(150, 147, 147);
}

# %% [markdown]
# 5. build a clone of the IRCTC Ticket booking page.

# %%
< !DOCTYPE html>
< html lang="en">
< head>
  < meta charset="UTF-8">
  < meta name="viewport" content="width=device-width, initial-scale=1.0">
  < title>IRCTC Booking Clone< /title>
  < style>
    * {
      margin: 0;
      padding: 0;
      box-sizing: border-box;
      font-family: 'Segoe UI', Arial, sans-serif;
    }

    body {
      background-color: #f5f5f5;
      display: flex;
      justify-content: center;
      align-items: center;
      min-height: 100vh;
    }

    .container {
      display: flex;
      width: 90%;
      max-width: 1200px;
      background: white;
      border-radius: 10px;
      box-shadow: 0 6px 20px rgba(0,0,0,0.1);
      overflow: hidden;
    }

    /* Left panel */
    .left {
      flex: 1;
      padding: 30px;
    }

    .logos {
      display: flex;
      align-items: center;
      gap: 15px;
      margin-bottom: 10px;
    }

    .logos img {
      height: 50px;
    }

    /* Top links (Ask Disha, Contact us, Alerts) */
    .top-links {
      display: flex;
      justify-content: flex-end;
      gap: 15px;
      font-size: 14px;
      margin-bottom: 8px;
    }

    .top-links a {
      color: #213d77;
      text-decoration: none;
      font-weight: 500;
    }

    .top-links a:hover {
      text-decoration: underline;
    }

    /* Login/Register buttons */
    .top-buttons {
      display: flex;
      justify-content: flex-end;
      gap: 10px;
      margin-bottom: 20px;
    }

    .top-buttons button {
      padding: 6px 14px;
      font-size: 14px;
      border: 1px solid #ccc;
      border-radius: 5px;
      cursor: pointer;
    }

    .top-buttons .login {
      background-color: #f05a28;
      color: white;
      border: none;
    }

    h1 {
      font-size: 24px;
      margin: 10px 0;
    }

    .subtitle span {
      font-weight: bold;
      margin-right: 10px;
    }
    .subtitle .green { color: green; }
    .subtitle .orange { color: orange; }
    .subtitle .blue { color: #213d77; }

    /* Navigation buttons */
    .nav-buttons {
      display: flex;
      gap: 10px;
      margin: 20px 0;
    }

    .nav-buttons button {
      padding: 10px 20px;
      border-radius: 6px;
      border: 1px solid #ccc;
      background: #f8f8f8;
      font-weight: 600;
      cursor: pointer;
    }

    .nav-buttons .active {
      background: #213d77;
      color: white;
      border: none;
    }

    /* Form box */
    .form-box {
      border: 1px solid #ddd;
      border-radius: 8px;
      padding: 20px;
    }

    .form-row {
      display: flex;
      justify-content: space-between;
      margin-bottom: 15px;
    }

    .form-group {
      flex: 1;
      margin-right: 10px;
    }

    .form-group:last-child {
      margin-right: 0;
    }

    label {
      font-size: 13px;
      color: #555;
      display: block;
      margin-bottom: 5px;
    }

    input, select {
      width: 100%;
      padding: 10px;
      border: 1px solid #ccc;
      border-radius: 6px;
    }

    /* Search Button */
    .search-btn {
      background: #28a745;
      color: white;
      padding: 14px;
      border: none;
      width: 100%;
      border-radius: 6px;
      font-size: 16px;
      font-weight: bold;
      cursor: pointer;
      margin-top: 15px;
    }

    .search-btn:hover {
      background: #218838;
    }

    /* Right panel */
    .right {
      flex: 1;
      background: url("vandebharat.png") no-repeat center center;
      background-size: cover;
      margin: 0;
    }
  < /style>
< /head>
< body>
  < div class="container">
    < !-- Left side -->
    < div class="left">
      < div class="logos">
        < img src="logo.png" alt="IRCTC Logo">
        < img src="logo2.png" alt="Indian Railways Logo">
      < /div>

      < !-- Ask Disha, Contact us, Alerts -->
      < div class="top-links">
        < a href="#">Ask Disha< /a>
        < a href="#">Contact us< /a>
        < a href="#">Alerts< /a>
      < /div>

      < !-- Login/Register -->
      < div class="top-buttons">
        < button class="login">Login< /button>
        < button>Register< /button>
        < button>Agent Login< /button>
      < /div>

      < h1>Indian Railways< /h1>
      < p class="subtitle">
        < span class="green">Safety< /span>
        < span class="orange">Security< /span>
        < span class="blue">Punctuality< /span>
      < /p>

      < div class="nav-buttons">
        < button class="active">BOOK Ticket< /button>
        < button>PNR Status< /button>
        < button>Charts / Vacancy< /button>
      < /div>

      < !-- Form -->
      < div class="form-box">
        < div class="form-row">
          < div class="form-group">
            < label for="from">From< /label>
            < input type="text" id="from" value="Bangalore">
          < /div>
          < div class="form-group">
            < label for="to">To< /label>
            < input type="text" id="to" value="Kasaragod">
          < /div>
        < /div>

        < div class="form-row">
          < div class="form-group">
            < label for="date">Date< /label>
            < input type="date" id="date" value="2023-08-01">
          < /div>
          < div class="form-group">
            < label for="class">Class< /label>
            < select id="class">
              < option>3A - AC 3 Tier< /option>
              < option>2A - AC 2 Tier< /option>
              < option>SL - Sleeper< /option>
              < option>1A - First Class< /option>
            < /select>
          < /div>
        < /div>

        < div class="form-row">
          < div class="form-group">
            < label for="quota">Seat Type< /label>
            < select id="quota">
              < option>TATKAL< /option>
              < option>GENERAL< /option>
              < option>LADIES< /option>
              < option>PREMIUM TATKAL< /option>
            < /select>
          < /div>
        < /div>

        < button class="search-btn">Search Train →< /button>
      < /div>
    < /div>

    < !-- Right side -->
    < div class="right">
      < img src="vandebharat.png" alt="">
    < /div>
  < /div>
< /body>
< /html>
